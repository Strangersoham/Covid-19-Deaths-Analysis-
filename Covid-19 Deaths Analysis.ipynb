# %% [markdown]
# ### Introduction

# %% [markdown]
# COVID-19 is an infectious disease caused by the Corona Virus, biologically known as severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). The disease was first identified in Wuhan, the capital of China's Hubei province in December 2019 and has spread all over the world since then. As of writing this, on 26th April 2020, 21:57 IST, there are 2.92 million confirmed cases throughout the world and has resulted in 204,000 deaths according to Google.
#
# In this notebook, I will take a look at the current situation in India. We will take a look at the regions which are most  effected by the outbreak and how numbers have steadily climbed in the country .

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
covid = pd.read_csv('covid_19_india.csv')

# %%
covid
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 1313  1314  25/04/20  5:00 PM            Telengana                       -
# 1314  1315  25/04/20  5:00 PM              Tripura                       -
# 1315  1316  25/04/20  5:00 PM          Uttarakhand                       -
# 1316  1317  25/04/20  5:00 PM        Uttar Pradesh                       -
# 1317  1318  25/04/20  5:00 PM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
covid.loc[covid['State/UnionTerritory'] == "Maharashtra"]
# Out:
#        Sno      Date      Time State/UnionTerritory ConfirmedIndianNational  \
# 76      77  09/03/20   6:00 PM          Maharashtra                       2
# 91      92  10/03/20   6:00 PM          Maharashtra                       5
# 97      98  11/03/20   6:00 PM          Maharashtra                       2
# 120    121  12/03/20   6:00 PM          Maharashtra                      11
# 133    134  13/03/20   6:00 PM          Maharashtra                      14
# 146    147  14/03/20   6:00 PM          Maharashtra                      14
# 153    154  15/03/20   6:00 PM          Maharashtra                      32
# 167    168  16/03/20   6:00 PM          Maharashtra                      32
# 182    183  17/03/20   6:00 PM          Maharashtra                      36
# 197    198  18/03/20   6:00 PM          Maharashtra                      39
# 215    216  19/03/20   6:00 PM          Maharashtra                      44
# ...

# %%
covid.loc[covid['State/UnionTerritory'] == "Telengana"]
# Out:
#        Sno      Date      Time State/UnionTerritory ConfirmedIndianNational  \
# 32      33  02/03/20   6:00 PM            Telengana                       1
# 35      36  03/03/20   6:00 PM            Telengana                       1
# 43      44  04/03/20   6:00 PM            Telengana                       1
# 49      50  05/03/20   6:00 PM            Telengana                       1
# 56      57  06/03/20   6:00 PM            Telengana                       1
# 60      61  07/03/20   6:00 PM            Telengana                       1
# 66      67  08/03/20   6:00 PM            Telengana                       1
# 80      81  09/03/20   6:00 PM            Telengana                       1
# 95      96  10/03/20   6:00 PM            Telengana                       1
# 102    103  11/03/20   6:00 PM            Telengana                       1
# 113    114  12/03/20   6:00 PM            Telengana                       1
# ...

# %%
covid.loc[covid['State/UnionTerritory'] == "Uttar Pradesh"]
# Out:
#        Sno      Date      Time State/UnionTerritory ConfirmedIndianNational  \
# 39      40  04/03/20   6:00 PM        Uttar Pradesh                       6
# 50      51  05/03/20   6:00 PM        Uttar Pradesh                       7
# 55      56  06/03/20   6:00 PM        Uttar Pradesh                       7
# 58      59  07/03/20   6:00 PM        Uttar Pradesh                       7
# 72      73  08/03/20   6:00 PM        Uttar Pradesh                       7
# 82      83  09/03/20   6:00 PM        Uttar Pradesh                       7
# 85      86  10/03/20   6:00 PM        Uttar Pradesh                       7
# 103    104  11/03/20   6:00 PM        Uttar Pradesh                       9
# 114    115  12/03/20   6:00 PM        Uttar Pradesh                      10
# 127    128  13/03/20   6:00 PM        Uttar Pradesh                      10
# 140    141  14/03/20   6:00 PM        Uttar Pradesh                      11
# ...

# %%
MH = covid.loc[covid['State/UnionTerritory'] == "Maharashtra"]
TS = covid.loc[covid['State/UnionTerritory'] == "Telengana"]
UP = covid.loc[covid['State/UnionTerritory'] == "Uttar Pradesh"]

# %%
plt.plot(TS.Date ,TS.Deaths,color= "red")
plt.xticks(TS.Date[::10])
plt.title('Increase in deaths due to Covid 19')
plt.xlabel('Date')
plt.ylabel('No. of Deaths')
plt.show()

# %%
plt.plot(MH.Date ,MH.Deaths,color= "blue")
plt.xticks(MH.Date[::10])
plt.title('Increase in deaths due to Covid 19')
plt.xlabel('Date')
plt.ylabel('No. of Deaths')
plt.show()

# %%
plt.plot(UP.Date ,UP.Deaths,color= "green")
plt.xticks(UP.Date[::10])
plt.title('Increase in deaths due to Covid 19')
plt.xlabel('Date')
plt.ylabel('No. of Deaths')
plt.show()

# %%
plt.plot(TS.Date ,TS.Deaths,color= "red", label="TS")
plt.plot(UP.Date ,UP.Deaths ,color= "green",label="UP")
plt.plot(MH.Date ,MH.Deaths ,color= "blue",label="MH")
plt.xticks(TS.Date[::10])
plt.title('Increase in deaths due to Covid 19')
plt.xlabel('Date')
plt.ylabel('No. of Deaths')
plt.legend()
plt.show()

# %%
covid.hist(column='Deaths')
plt.show()

# %%
plt.figure(figsize=(20,10))
covid['State/UnionTerritory'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
from matplotlib import rcParams
rcParams['figure.figsize']= 10,6
plt.grid(True)
plt.plot(TS.Date ,TS.Confirmed,color= "red", label="TS")
plt.plot(UP.Date ,UP.Deaths ,color= "green",label="UP")
plt.plot(MH.Date ,MH.Deaths ,color= "blue",label="MH")
plt.xticks(TS.Date[::10])
plt.title('Increase in deaths due to Covid 19')
plt.xlabel('Date')
plt.ylabel('No. of Deaths')
plt.legend() 
plt.show()

# %%
rcParams['figure.figsize']= 10,6
plt.grid(True)
plt.plot(TS.Date ,TS.Confirmed,color= "red", label="TS")
plt.plot(UP.Date ,UP.Confirmed ,color= "green",label="UP")
plt.plot(MH.Date ,MH.Confirmed ,color= "blue",label="MH")
plt.xticks(TS.Date[::10])
plt.title('Increase in no. of Confirmed cases')
plt.xlabel('Date')
plt.ylabel('No. of Confirmed cases')
plt.legend()
plt.show()
